# %%
import pandas as pd
import os
from DATA_LLENADO import llenado

# %%
lista_files = os.listdir("datos/")
lista_files = [i for i in os.listdir("datos/") if i != '.DS_Store']  #Seleccionar CSVs y excluir archivo oculto de macOS.

# %%
resul = llenado("datos/", lista_files)
resul
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 resul = llenado("datos/", lista_files)
#       2 resul
#
# File ~/Desktop/AQUALOGS_GH/DATA_ANALISIS/DATA_LLENADO.py:53, in llenado(path_pre, lista_files)
#      51 """Llamar datos csv por estación"""
#      52 for i in np.arange(0,len(lista_files),1):
# ---> 53     data = pd.read_csv(path_pre + lista_files[i]); data = data[['Fecha', 'Valor']]; data = data.set_index('Fecha');data.index = pd.to_datetime(data.index)
#      54     data = data.loc[año_ini + '-' + mes_ini +  '-' + dia_ini: año_fin + '-' + mes_fin +  '-' + dia_fin]
#      55     fecha_inicio = np.append(fecha_inicio,data.index[0].strftime('%Y-%m-%d'))
#
# ...

# %%
lat   = resul[['Fecha', 'Latitud']]

# %%
lat
# Out:
#                   Fecha    Latitud
# 0      1995-01-01 00:00  11.137583
# 1      1995-01-02 00:00  11.137583
# 2      1995-01-03 00:00  11.137583
# 3      1995-01-04 00:00  11.137583
# 4      1995-01-05 00:00  11.137583
# ...                 ...        ...
# 10229  2023-06-24 00:00  11.137583
# 10230  2023-06-25 00:00  11.137583
# 10231  2023-06-26 00:00  11.137583
# 10232  2023-06-27 00:00  11.137583
# 10233  2023-06-29 00:00  11.137583
#
# [10234 rows x 2 columns]

# %%
año_ini = '1995'
mes_ini = '01'
dia_ini = '01'

año_fin = '2023'
mes_fin = '06'
dia_fin = '30'

# %%
path_pre = "datos/"
i = 1
data  = pd.read_csv(path_pre + lista_files[i])

valor = data[['Fecha', 'Valor']]
valor = valor.rename({'Valor': i}, axis = 1)
valor = valor.set_index('Fecha')
valor.index = pd.to_datetime(valor.index)
valor = valor.loc[año_ini + '-' + mes_ini +  '-' + dia_ini: año_fin + '-' + mes_fin +  '-' + dia_fin]

lat   = data[['Fecha', 'Latitud']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 11
#       8 valor.index = pd.to_datetime(valor.index)
#       9 valor = valor.loc[año_ini + '-' + mes_ini +  '-' + dia_ini: año_fin + '-' + mes_fin +  '-' + dia_fin]
# ---> 11 lat   = data[['Fecha', 'Latitud']]
#
# File ~/anaconda3/envs/hidro/lib/python3.9/site-packages/pandas/core/frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# File ~/anaconda3/envs/hidro/lib/python3.9/site-packages/pandas/core/indexes/base.py:6115, in Index._get_indexer_strict(self, key, axis_name)
#    6112 else:
#    6113     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %%
data
# Out:
#                      Fecha  Valor
# 0      1990-01-01 00:00:00    NaN
# 1      1990-01-02 00:00:00    NaN
# 2      1990-01-03 00:00:00    NaN
# 3      1990-01-04 00:00:00    NaN
# 4      1990-01-05 00:00:00    NaN
# ...                    ...    ...
# 12331  2023-10-06 00:00:00   18.5
# 12332  2023-10-07 00:00:00    0.0
# 12333  2023-10-08 00:00:00    0.0
# 12334  2023-10-09 00:00:00    0.0
# 12335  2023-10-10 00:00:00   58.5
#
# [12336 rows x 2 columns]

# %%
lat   = lat.rename({'Latitud': i}, axis = 1)

# %%
lat
# Out:
#                   Fecha          0
# 0      1995-01-01 00:00  11.137583
# 1      1995-01-02 00:00  11.137583
# 2      1995-01-03 00:00  11.137583
# 3      1995-01-04 00:00  11.137583
# 4      1995-01-05 00:00  11.137583
# ...                 ...        ...
# 10229  2023-06-24 00:00  11.137583
# 10230  2023-06-25 00:00  11.137583
# 10231  2023-06-26 00:00  11.137583
# 10232  2023-06-27 00:00  11.137583
# 10233  2023-06-29 00:00  11.137583
#
# [10234 rows x 2 columns]

# %%
lat
# Out:
#                   Fecha    Latitud
# 0      1995-01-01 00:00  11.137583
# 1      1995-01-02 00:00  11.137583
# 2      1995-01-03 00:00  11.137583
# 3      1995-01-04 00:00  11.137583
# 4      1995-01-05 00:00  11.137583
# ...                 ...        ...
# 10229  2023-06-24 00:00  11.137583
# 10230  2023-06-25 00:00  11.137583
# 10231  2023-06-26 00:00  11.137583
# 10232  2023-06-27 00:00  11.137583
# 10233  2023-06-29 00:00  11.137583
#
# [10234 rows x 2 columns]
